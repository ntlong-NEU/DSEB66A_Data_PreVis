# %% [markdown]
# ## Lecture 01: Pandas

# %%
import numpy as pd
import pandas as pd

# %%
# Series: Population by Country Code
country_population = pd.Series(
     data=[61, 46, 11, 65, 10],
    index=["IT", "ES", "GR", "FR", "PO"],
    name="Country Population"
)
country_population
data = {
    "Name": [
         "Avery Bradley", "John Holland", "Jonas Jerebko",
        "Jordan Mickey", "Terry Rozier", "Jared Sullinger", "Evan Turner"
    ],
    "Team": ["Boston Celtics"] * 7,
     "Number": [0.0, 30.0, 8.0, None, 12.0, 7.0, 11.0],
     "Position": ["PG", "SG", "PF", "PF", "PG", "C", "SG"],
     "Age": [25.0, 27.0, 29.0, 21.0, 22.0, None, 27.0]
}
df_0 = pd.DataFrame(data)

# %%
df_0
# Out:
#               Name            Team  Number Position   Age
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0
# 1     John Holland  Boston Celtics    30.0       SG  27.0
# 2    Jonas Jerebko  Boston Celtics     8.0       PF  29.0
# 3    Jordan Mickey  Boston Celtics     NaN       PF  21.0
# 4     Terry Rozier  Boston Celtics    12.0       PG  22.0
# 5  Jared Sullinger  Boston Celtics     7.0        C   NaN
# 6      Evan Turner  Boston Celtics    11.0       SG  27.0

# %%
df_0.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df_0.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age'], dtype='object')

# %%
df_0.columns[2] ='sdfsf'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_0.columns[2] ='sdfsf'
#
# File d:\CODE\env-teaching\Lib\site-packages\pandas\core\indexes\base.py:5371, in Index.__setitem__(self, key, value)
#    5369 @final
#    5370 def __setitem__(self, key, value) -> None:
# -> 5371     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
country_population
# Out:
# IT    61
# ES    46
# GR    11
# FR    65
# PO    10
# Name: Country Population, dtype: int64

# %%
country_population.index #immutable
# Out:
# Index(['IT', 'ES', 'GR', 'FR', 'PO'], dtype='object')

# %%
country_population
# Out:
# IT    61
# ES    46
# GR    11
# FR    65
# PO    10
# Name: Country Population, dtype: int64

# %%
country_population[1]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18592\2605600934.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   country_population[1]
# np.int64(46)

# %%
country_population['GR']
# Out:
# np.int64(11)

# %%
country_population[:2]
# Out:
# IT    61
# ES    46
# Name: Country Population, dtype: int64

# %%
country_population
# Out:
# IT    61
# ES    46
# GR    11
# FR    65
# PO    10
# Name: Country Population, dtype: int64

# %%
country_population[:'GR']
# Out:
# IT    61
# ES    46
# GR    11
# Name: Country Population, dtype: int64

# %%
df_0
# Out:
#               Name            Team  Number Position   Age
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0
# 1     John Holland  Boston Celtics    30.0       SG  27.0
# 2    Jonas Jerebko  Boston Celtics     8.0       PF  29.0
# 3    Jordan Mickey  Boston Celtics     NaN       PF  21.0
# 4     Terry Rozier  Boston Celtics    12.0       PG  22.0
# 5  Jared Sullinger  Boston Celtics     7.0        C   NaN
# 6      Evan Turner  Boston Celtics    11.0       SG  27.0

# %%
df_0['Name']
# Out:
# 0      Avery Bradley
# 1       John Holland
# 2      Jonas Jerebko
# 3      Jordan Mickey
# 4       Terry Rozier
# 5    Jared Sullinger
# 6        Evan Turner
# Name: Name, dtype: object

# %%
df_0['Number']
# Out:
# 0     0.0
# 1    30.0
# 2     8.0
# 3     NaN
# 4    12.0
# 5     7.0
# 6    11.0
# Name: Number, dtype: float64

# %%
df_0[['Name','Number']]#fancy index
# Out:
#               Name  Number
# 0    Avery Bradley     0.0
# 1     John Holland    30.0
# 2    Jonas Jerebko     8.0
# 3    Jordan Mickey     NaN
# 4     Terry Rozier    12.0
# 5  Jared Sullinger     7.0
# 6      Evan Turner    11.0

# %%
df_0
# Out:
#               Name            Team  Number Position   Age
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0
# 1     John Holland  Boston Celtics    30.0       SG  27.0
# 2    Jonas Jerebko  Boston Celtics     8.0       PF  29.0
# 3    Jordan Mickey  Boston Celtics     NaN       PF  21.0
# 4     Terry Rozier  Boston Celtics    12.0       PG  22.0
# 5  Jared Sullinger  Boston Celtics     7.0        C   NaN
# 6      Evan Turner  Boston Celtics    11.0       SG  27.0

# %%
df_0.iloc[:2,:3]
# Out:
#             Name            Team  Number
# 0  Avery Bradley  Boston Celtics     0.0
# 1   John Holland  Boston Celtics    30.0

# %%
country_population[1]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18592\2605600934.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   country_population[1]
# np.int64(46)

# %%
country_population.iloc[1]
# Out:
# np.int64(46)

# %%
data = {'Province': ['Hanoi', 'HCMC', 'Danang'],
         'Population (millions)': [8.05, 8.99, 1.13]}
df = pd.DataFrame(data)

# %%
df.index = list('abc')
df
# Out:
#   Province  Population (millions)
# a    Hanoi                   8.05
# b     HCMC                   8.99
# c   Danang                   1.13

# %%
df.iloc[0]
# Out:
# Province                 Hanoi
# Population (millions)     8.05
# Name: a, dtype: object

# %%
df.loc['a']
# Out:
# Province                 Hanoi
# Population (millions)     8.05
# Name: a, dtype: object

# %%
country_population
# Out:
# IT    61
# ES    46
# GR    11
# FR    65
# PO    10
# Name: Country Population, dtype: int64

# %%
df_0[df_0['Age']>22]
# Out:
#             Name            Team  Number Position   Age
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0
# 1   John Holland  Boston Celtics    30.0       SG  27.0
# 2  Jonas Jerebko  Boston Celtics     8.0       PF  29.0
# 6    Evan Turner  Boston Celtics    11.0       SG  27.0

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df_lab0 = sns.load_dataset('titanic')
df_lab0.head() #default = 5
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_lab0['survived'].mean()
# Out:
# np.float64(0.3838383838383838)

# %%
female_ratio = df_lab0[df_lab0['sex'] == 'female']['survived'].mean()
male_ratio = df_lab0[df_lab0['sex'] == 'male']['survived'].mean()
print(female_ratio)
print(male_ratio)
# Out:
# 0.7420382165605095
# 0.18890814558058924
